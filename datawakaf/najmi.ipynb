# %%
import pandas as pd
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

# %%
data = pd.read_html('https://siwak.kemenag.go.id/siwak/tanah_wakaf_kab.php?_pid=cVFaODV0Sm5FVG1jb1hqSEFvbDJyUT09&_kid=aDY5SzVGOUhyL3JiTllqdVdVTkdSZz09')
df = pd.DataFrame(data[0])
df
# Out:
#         No Kantor Urusan Agama Jumlah Luas [Ha] Sudah Sertifikat            \
#         No Kantor Urusan Agama Jumlah Luas [Ha]           Jumlah Luas [Ha]
# 0       1.               JAWAI     76      1601               65       988
# 1       2.               PALOH     30       704               22       636
# 2       3.           PEMANGKAT     63      1042               53       861
# 3       4.              SAMBAS     76       433               54       153
# 4       5.          SEJANGKUNG     52      2103               26       811
# 5       6.             SELAKAU     26       323               16       163
# 6       7.               TEBAS    114      1640               93      1431
# 7       8.       TELUK KERAMAT    153      5337              121      3764
# 8       9.      SAJINGAN BESAR      5        13                1         2
# 9      10.              GALING     83      5298                4        33
# ...

# %%
df.to_excel('wakaf_sambas.xlsx')
