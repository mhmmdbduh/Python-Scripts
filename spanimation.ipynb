# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib.animation import FFMpegWriter

plt.rcParams['animation.ffmpeg_path'] = 'C:\\Users\\inazu\\Downloads\\paspor\\ffmpeg-2023-09-07-git-9c9f48e7f2-full_build\\bin\\ffmpeg.exe'

# %%
data = pd.read_csv('sp500_index.csv')
df = pd.DataFrame(data)
                  
df.head()

# %%
plt.plot(df['Date'], df['S&P500'],'o')

# %%
# metadata = dict(title='Movie', artist='Abduh')
# writer = FFMpegWriter(fps = 15, metadata=metadata)
# date = []
# price = []
# with writer.saving(fig, 'sinWave.mp4', 100):
#     for i in range(len(df)):
#         date.append(df['Date'][i])
#         price.append(df['S&P500'][i])
#         l.set_data(price, date)
#         writer.grab_frame()
